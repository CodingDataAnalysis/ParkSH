# %%
import itertools
import platform
import matplotlib
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
import seaborn as sns
# %precision 3
from matplotlib import pyplot as plt
# %matplotlib inline
#그래프를 주피터 놋북에 그리기 위해
import numpy as np
import copy
from matplotlib import ticker
from scipy.stats import probplot
from scipy import stats
import collections
import itertools
import math
#from varname import nameof
import sys
from scipy import stats
from scipy.stats import bernoulli
import scipy
from collections import deque
from sympy import Symbol, solve

#히스토그램 그리기
# Window
if platform.system() == 'Windows':
    matplotlib.rc('font', family='Malgun Gothic')
elif platform.system() == 'Darwin': # Mac
    matplotlib.rc('font', family='AppleGothic')
else: #linux
    matplotlib.rc('font', family='NanumGothic')

# 그래프에 마이너스 표시가 되도록 변경
matplotlib.rcParams['axes.unicode_minus'] = False

# 한글 폰트 설정
font_location = 'C:/Windows/Fonts/MALGUNSL.TTF' #맑은고딕
font_name = font_manager.FontProperties(fname=font_location).get_name()
rc('font',family=font_name)

# %%
import pandas as pd

data_path = '../data-science-london-scikit-learn/'

train = pd.read_csv(data_path + 'train.csv' , header = None)
test = pd.read_csv(data_path + 'test.csv' , header = None)
trainLabels = pd.read_csv(data_path + 'trainLabels.csv' , header = None)

# %%
train
# Out:
#            0         1         2         3          4         5         6   \
# 0    0.299403 -1.226624  1.498425 -1.176150   5.289853  0.208297  2.404498
# 1   -1.174176  0.332157  0.949919 -1.285328   2.199061 -0.151268 -0.427039
# 2    1.192222 -0.414371  0.067054 -2.233568   3.658881  0.089007  0.203439
# 3    1.573270 -0.580318 -0.866332 -0.603812   3.125716  0.870321 -0.161992
# 4   -0.613071 -0.644204  1.112558 -0.032397   3.490142 -0.011935  1.443521
# ..        ...       ...       ...       ...        ...       ...       ...
# 995 -0.310429  0.826811 -0.952245  0.768850   1.877520  1.320646  1.944609
# 996 -1.853879  0.246726  0.459921 -2.074267   7.599220 -0.138355 -4.501900
# 997  0.912748 -1.734039 -1.047035  0.217573  13.457812  0.162771 -2.250521
# 998  2.439780 -0.735511 -0.902426  1.365036 -10.430299 -0.856859  2.686474
# 999  0.228994 -0.085453  0.876582  1.057401  -1.404015 -1.091965  0.639176
#
#            7         8         9   ...        30        31        32  \
# 0    1.594506 -0.051608  0.663234  ... -0.850465 -0.622990 -1.833057
# 1    2.619246 -0.765884 -0.093780  ... -0.819750  0.012037  2.038836
# 2   -4.219054 -1.184919 -1.240310  ... -0.604501  0.750054 -3.360521
# 3    4.499666  1.038741 -1.092716  ...  1.022959  1.275598 -3.480110
# 4   -4.290282 -1.761308  0.807652  ...  0.513906 -1.803473  0.518579
# ..        ...       ...       ...  ...       ...       ...       ...
# 995  1.191420 -0.127724  0.070937  ... -0.600411 -0.383792  0.745596
# 996  0.630634 -1.590533 -1.112949  ...  0.361736  0.240052 -0.856196
# 997  2.216161 -0.378326  0.642114  ...  1.195896 -1.073806 -2.754369
# 998  0.292035  0.585388 -0.876965  ...  2.262326 -0.039488  0.773876
# 999  0.701332 -0.906577 -0.390940  ...  0.471415  1.024757 -1.796571
#
# 3     0.285646  2.302069  1.255588 -1.563090 -0.125258 -1.030761 -2.945329
# 4     0.372992  0.450700 -0.211657  1.301359 -0.522164  2.484883  0.039213
# ...        ...       ...       ...       ...       ...       ...       ...
# 8995  0.243930 -1.151233 -0.274298  0.573013  1.109814 -1.905965  1.457601
# 8996 -0.322943  1.964519  0.122384  0.678023  2.024129  0.386542  1.104493
# 8997  0.242725  0.670161  0.112752 -3.006949  1.179606  1.156340 -1.218561
# 8998  1.159658 -1.957241  0.482533  3.777669 -0.424954  1.333374  2.325271
# 8999 -0.352201  0.152333 -1.772249  0.758809  0.617485  1.464438  3.301445
#
# [9000 rows x 40 columns]

# %%
trainLabels = trainLabels.rename(columns={0: 'predict'})
trainLabels
# Out:
#      predict
# 0          1
# 1          0
# 2          0
# 3          1
# 4          0
# ..       ...
# 995        0
# 996        1
# 997        1
# 998        0
# 999        0
#
# [1000 rows x 1 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 40 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       1000 non-null   float64
#  1   1       1000 non-null   float64
#  2   2       1000 non-null   float64
#  3   3       1000 non-null   float64
#  4   4       1000 non-null   float64
#  5   5       1000 non-null   float64
#  6   6       1000 non-null   float64
#  7   7       1000 non-null   float64
#  8   8       1000 non-null   float64
#  9   9       1000 non-null   float64
#  10  10      1000 non-null   float64
#  11  11      1000 non-null   float64
#  12  12      1000 non-null   float64
#  13  13      1000 non-null   float64
#  14  14      1000 non-null   float64
#  15  15      1000 non-null   float64
#  16  16      1000 non-null   float64
#  17  17      1000 non-null   float64
#  18  18      1000 non-null   float64
#  19  19      1000 non-null   float64
#  20  20      1000 non-null   float64
#  21  21      1000 non-null   float64
#  22  22      1000 non-null   float64
#  23  23      1000 non-null   float64
#  24  24      1000 non-null   float64
#  25  25      1000 non-null   float64
#  26  26      1000 non-null   float64
#  27  27      1000 non-null   float64
#  28  28      1000 non-null   float64
#  29  29      1000 non-null   float64
#  30  30      1000 non-null   float64
#  31  31      1000 non-null   float64
#  32  32      1000 non-null   float64
#  33  33      1000 non-null   float64
#  34  34      1000 non-null   float64
#  35  35      1000 non-null   float64
#  36  36      1000 non-null   float64
#  37  37      1000 non-null   float64
#  38  38      1000 non-null   float64
#  39  39      1000 non-null   float64
# dtypes: float64(40)
# memory usage: 312.6 KB

# %%
train.describe()
# Out:
#                 0            1            2            3            4   \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      0.025596    -0.024526    -0.024088    -0.002271     1.092329
# std       1.008282     1.016298     0.979109     0.970575     4.538834
# min      -3.365711    -3.492086    -2.695602    -3.460471   -16.421901
# 25%      -0.669010    -0.693937    -0.698830    -0.617557    -1.801997
# 50%       0.027895    -0.033194     0.008145     0.002327     0.862818
# 75%       0.762520     0.682753     0.661434     0.640743     3.843172
# max       3.326246     3.583870     2.546507     3.088738    17.565345
#
#                 5            6            7            8            9   ...  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000  ...
# mean     -0.006250     0.497342    -0.037883     0.026391    -0.003597  ...
# std       0.989128     2.118819     2.232256     1.001064     1.013520  ...
# min      -3.041250    -7.224761    -6.509084    -3.145588    -2.749812  ...
# 25%      -0.732265    -0.838619    -1.604037    -0.677562    -0.682220  ...
# 50%       0.027041     0.582321     0.018809     0.022092    -0.036110  ...
# 75%       0.671456     1.913664     1.438304     0.741310     0.665364  ...
# max       3.102997     7.592666     7.130097     3.145258     3.919426  ...
#
#                 30           31           32           33           34  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      0.030651     0.022951    -0.542491    -0.011608    -0.483507
# std       1.011645     1.001375     2.239939     1.022456     2.121281
# min      -3.379194    -2.971125    -7.840890    -2.999564    -7.124105
# 25%      -0.659457    -0.696032    -2.121943    -0.664550    -1.879247
# 50%       0.049416     0.049778    -0.568262    -0.028097    -0.493575
# 75%       0.747031     0.699917     0.939348     0.651374     1.005795
# max       2.844792     3.688047     7.160379     3.353631     6.005818
#
#                 35           36           37           38           39
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      0.033371     0.567185     0.006849    -0.892659     0.609451
# std       1.007044     2.227876     0.997635     2.022022     2.045439
# min      -2.952358    -5.452254    -3.473913    -8.051722    -7.799086
# 25%      -0.642861    -1.059786    -0.691162    -2.220126    -0.565041
# 50%       0.037732     0.455474     0.038284    -0.855470     0.779944
# 75%       0.691800     2.122157     0.693535     0.388698     1.992193
# max       3.420561     6.603499     3.492548     5.774120     6.803984
#
# [8 rows x 40 columns]

# %% [markdown]
# ## XGBclassifier

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from xgboost import XGBClassifier
# Train 데이터의 인덱스를 타깃 변수로 사용하여 이진 분류 수행
X = train
y = trainLabels

# 훈련 데이터와 테스트 데이터 분리
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# 이진 분류 모델 생성 및 학습
model = XGBClassifier()
model.fit(X_train, y_train)

# 모델 평가
y_pred = model.predict(X_test)
y_pred
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.88

# %%
y_preds = model.predict(test)

# 기존의 df_preds 데이터프레임
# df_preds = pd.DataFrame(y_preds)

df_preds = pd.DataFrame(y_preds)
df_preds.columns = ['Solution']
df_preds.index = df_preds.index + 1
df_preds.index.name = 'Id'

df_preds
# Out:
#       Solution
# Id
# 1            1
# 2            0
# 3            0
# 4            0
# 5            0
# ...        ...
# 8996         1
# 8997         1
# 8998         1
# 8999         0
# 9000         1
#
# [9000 rows x 1 columns]

# %% [markdown]
# ## LightGBM

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
# Train 데이터의 인덱스를 타깃 변수로 사용하여 이진 분류 수행
X = train
y = trainLabels

# 훈련 데이터와 테스트 데이터 분리
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# 이진 분류 모델 생성 및 학습
model = LGBMClassifier()
model.fit(X_train, y_train)

# 모델 평가
y_pred = model.predict(X_test)
y_pred
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# C:\Users\andyp\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:99: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\andyp\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:134: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# Accuracy: 0.875

# %%
y_preds = model.predict(test)

# 기존의 df_preds 데이터프레임
# df_preds = pd.DataFrame(y_preds)

df_preds = pd.DataFrame(y_preds)
df_preds.columns = ['Solution']
df_preds.index = df_preds.index + 1
df_preds.index.name = 'Id'

df_preds
# Out:
#       Solution
# Id
# 1            1
# 2            0
# 3            0
# 4            0
# 5            0
# ...        ...
# 8996         1
# 8997         1
# 8998         1
# 8999         0
# 9000         1
#
# [9000 rows x 1 columns]

# %% [markdown]
# ## CatBoost

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
# Train 데이터의 인덱스를 타깃 변수로 사용하여 이진 분류 수행
X = train
y = trainLabels

# 훈련 데이터와 테스트 데이터 분리
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# 이진 분류 모델 생성 및 학습
model = CatBoostClassifier()
model.fit(X_train, y_train)

# 모델 평가
y_pred = model.predict(X_test)
y_pred
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Learning rate set to 0.009366
# 0:	learn: 0.6887477	total: 24.7ms	remaining: 24.7s
# 1:	learn: 0.6837491	total: 48.4ms	remaining: 24.2s
# 2:	learn: 0.6781998	total: 67.5ms	remaining: 22.4s
# 3:	learn: 0.6734280	total: 95.9ms	remaining: 23.9s
# 4:	learn: 0.6681947	total: 127ms	remaining: 25.2s
# 5:	learn: 0.6617077	total: 148ms	remaining: 24.5s
# 6:	learn: 0.6566521	total: 167ms	remaining: 23.7s
# 7:	learn: 0.6512215	total: 191ms	remaining: 23.7s
# 8:	learn: 0.6467616	total: 223ms	remaining: 24.6s
# 9:	learn: 0.6421278	total: 258ms	remaining: 25.5s
# 10:	learn: 0.6370752	total: 284ms	remaining: 25.5s
# 11:	learn: 0.6331375	total: 313ms	remaining: 25.8s
# 12:	learn: 0.6292556	total: 358ms	remaining: 27.2s
# 13:	learn: 0.6249918	total: 391ms	remaining: 27.5s
# 14:	learn: 0.6210921	total: 420ms	remaining: 27.6s
# 15:	learn: 0.6156638	total: 441ms	remaining: 27.1s
# 16:	learn: 0.6108394	total: 466ms	remaining: 27s
# 17:	learn: 0.6067620	total: 484ms	remaining: 26.4s
# 18:	learn: 0.6023401	total: 500ms	remaining: 25.8s
# 19:	learn: 0.5972895	total: 539ms	remaining: 26.4s
# 20:	learn: 0.5930273	total: 575ms	remaining: 26.8s
# 21:	learn: 0.5896531	total: 594ms	remaining: 26.4s
# 22:	learn: 0.5863630	total: 615ms	remaining: 26.1s
# 23:	learn: 0.5822184	total: 639ms	remaining: 26s
# 24:	learn: 0.5792210	total: 655ms	remaining: 25.6s
# 25:	learn: 0.5740988	total: 678ms	remaining: 25.4s
# 26:	learn: 0.5694630	total: 699ms	remaining: 25.2s
# 27:	learn: 0.5661697	total: 722ms	remaining: 25.1s
# 28:	learn: 0.5617132	total: 736ms	remaining: 24.6s
# 29:	learn: 0.5570055	total: 751ms	remaining: 24.3s
# 30:	learn: 0.5535951	total: 766ms	remaining: 23.9s
# 31:	learn: 0.5506892	total: 783ms	remaining: 23.7s
# 972:	learn: 0.0620516	total: 14.9s	remaining: 412ms
# 973:	learn: 0.0619687	total: 14.9s	remaining: 397ms
# 974:	learn: 0.0618288	total: 14.9s	remaining: 382ms
# 975:	learn: 0.0617443	total: 14.9s	remaining: 367ms
# 976:	learn: 0.0616931	total: 14.9s	remaining: 351ms
# 977:	learn: 0.0616044	total: 14.9s	remaining: 336ms
# 978:	learn: 0.0614644	total: 15s	remaining: 321ms
# 979:	learn: 0.0613970	total: 15s	remaining: 305ms
# 980:	learn: 0.0613297	total: 15s	remaining: 290ms
# 981:	learn: 0.0612603	total: 15s	remaining: 275ms
# 982:	learn: 0.0611307	total: 15s	remaining: 259ms
# 983:	learn: 0.0609670	total: 15s	remaining: 244ms
# 984:	learn: 0.0608937	total: 15s	remaining: 229ms
# 985:	learn: 0.0607852	total: 15s	remaining: 213ms
# 986:	learn: 0.0606830	total: 15s	remaining: 198ms
# 987:	learn: 0.0605372	total: 15.1s	remaining: 183ms
# 988:	learn: 0.0604123	total: 15.1s	remaining: 168ms
# 989:	learn: 0.0603605	total: 15.1s	remaining: 152ms
# 990:	learn: 0.0602844	total: 15.1s	remaining: 137ms
# 991:	learn: 0.0601890	total: 15.1s	remaining: 122ms
# 992:	learn: 0.0600237	total: 15.1s	remaining: 106ms
# 993:	learn: 0.0599498	total: 15.1s	remaining: 91.3ms
# 994:	learn: 0.0597480	total: 15.1s	remaining: 76ms
# 995:	learn: 0.0596213	total: 15.1s	remaining: 60.8ms
# 996:	learn: 0.0594799	total: 15.2s	remaining: 45.6ms
# 997:	learn: 0.0593559	total: 15.2s	remaining: 30.4ms
# 998:	learn: 0.0592885	total: 15.2s	remaining: 15.2ms
# 999:	learn: 0.0592292	total: 15.2s	remaining: 0us
# Accuracy: 0.915

# %%
y_preds = model.predict(test)

# 기존의 df_preds 데이터프레임
# df_preds = pd.DataFrame(y_preds)

df_preds = pd.DataFrame(y_preds)
df_preds.columns = ['Solution']
df_preds.index = df_preds.index + 1
df_preds.index.name = 'Id'

df_preds
# Out:
#       Solution
# Id
# 1            1
# 2            0
# 3            0
# 4            0
# 5            0
# ...        ...
# 8996         1
# 8997         1
# 8998         1
# 8999         0
# 9000         1
#
# [9000 rows x 1 columns]

# %%
# import datetime
#
# # 현재 날짜와 시각 구하기
# now = datetime.datetime.now()
# date_list = [now.month, now.day, now.hour, now.minute, now.second]
# # 현재 날짜와 시각 출력하기
# print("현재 날짜 및 시각 : ", date_list)
#
# # 제출 파일 생성
#
# # submission['Survived'] = y_preds
# df_preds.to_csv(f'CatBoostClassifier_{date_list[0]}_{date_list[1]}_{date_list[2]}_{date_list[3]}_{date_list[4]}.csv')

# %% [markdown]
# ## RandomForest

# %%
from flake8.style_guide import Decision
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier

# Train 데이터의 인덱스를 타깃 변수로 사용하여 이진 분류 수행
X = train
y = trainLabels

# 훈련 데이터와 테스트 데이터 분리
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# 이진 분류 모델 생성 및 학습
model = RandomForestClassifier()
model.fit(X_train, y_train)

# 모델 평가
y_pred = model.predict(X_test)
y_pred
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# <ipython-input-35-7586d7514b07>:19: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(X_train, y_train)
# Accuracy: 0.865

# %%
y_preds = model.predict(test)

# 기존의 df_preds 데이터프레임
# df_preds = pd.DataFrame(y_preds)

df_preds = pd.DataFrame(y_preds)
df_preds.columns = ['Solution']
df_preds.index = df_preds.index + 1
df_preds.index.name = 'Id'

df_preds
# Out:
#       Solution
# Id
# 1            1
# 2            0
# 3            0
# 4            0
# 5            0
# ...        ...
# 8996         0
# 8997         1
# 8998         1
# 8999         0
# 9000         1
#
# [9000 rows x 1 columns]

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from sklearn.tree import DecisionTreeClassifier

# Train 데이터의 인덱스를 타깃 변수로 사용하여 이진 분류 수행
X = train
y = trainLabels

# 훈련 데이터와 테스트 데이터 분리
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# 이진 분류 모델 생성 및 학습
model = DecisionTreeClassifier()
model.fit(X_train, y_train)

# 모델 평가
y_pred = model.predict(X_test)
y_pred
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.775

# %%
# import datetime
#
# # 현재 날짜와 시각 구하기
# now = datetime.datetime.now()
# date_list = [now.month, now.day, now.hour, now.minute, now.second]
# # 현재 날짜와 시각 출력하기
# print("현재 날짜 및 시각 : ", date_list)
#
# # 제출 파일 생성
#
# # submission['Survived'] = y_preds
# df_preds.to_csv(f'XGBClassifier_{date_list[0]}_{date_list[1]}_{date_list[2]}_{date_list[3]}_{date_list[4]}.csv')

# %% [markdown]
# ## 베이지안 활용한 XGBoostRegreesion 돌려보기

# %%
from sklearn.metrics import mean_absolute_error


def mae_scorer(preds, dtrain):
    labels = dtrain.get_label()
    return 'Mae' , mean_absolute_error(labels, preds)

# %%
from sklearn.metrics import accuracy_score


def accuracy_scorer(preds, dtrain):
    labels = dtrain.get_label()
    preds_binary = (preds > 0.5).astype(int)
    return 'accuracy', accuracy_score(labels, preds_binary)
#
# def accuracy_scorer(preds, dtrain):
#     y_true = dtrain.get_label()
#     y_pred = (preds > 0.5).astype(int)
#     accuracy = accuracy_score(y_true, y_pred)
#     return accuracy

# %%
from scipy import sparse
from sklearn.model_selection import train_test_split
import xgboost as xgb
#
X = sparse.csr_matrix(train)
X_test = sparse.csr_matrix(test)


y = trainLabels['predict'].values


# 훈련 데이터와 테스트 데이터 분리
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.2, random_state=0)

# 베이지안 최적화용 데이터셋

bayes_dtrain = xgb.DMatrix(X_train , y_train)
bayes_dvalid = xgb.DMatrix(X_valid, y_valid)

# %%
# 베이지안 최적화를 위한 하이퍼파라미터 범위
param_bounds = {'max_depth' : (4 , 10) , # 개별 트리의 최대 깊이, 트리 깊이가 깊을수록 모델이 복잡해지고 과대적합 우려
                # 값이 클수록 깊이가 한 단계만 늘어나도 메모리 사용량이 급격히 많아진다.
                # 일반적으로 3~10 사이의 값을 주로 사용한다.

                'subsample' : (0.5 , 1), # 개별 트리를 훈련할 때 사용할 데이터 샘플링 비율
                # 0~1 사이 값으로 설정할 수 있다.
                # 0.5 로 설정하면 전체 데이터의 50%를 사용해 트리를 생성

                'colsample_bytree' : (0.3 , 1.0), # 개별 트리를 훈련할 때 사용하는 피처 샘플링 비율
                # subsample 과 유사한 개념, subsample은 전체 데이터에서 얼마나 샘플링할지 나타내는 비율
                # colsample_bytree는 전체 피처에서 얼마나 샘플링할지 나타내는 비율
                # 값이 작을수록 과대적합 방지 효과

                'min_child_weight' : (5 , 10), # 과대적합 방지위한 값, 값이 클수록 과대적합 방지 효과가 있다.
                'gamma' : (8 , 11), # 말단 노드가 분할하기 위한 최소 손실 감소 값
                # 소실 감소가 gamma보다 크면 말단 노드를 분할
                # 값이 클수록 과대적합 방지 효과가 있다.

                'reg_alpha' : (7 , 9) , # L1 규제 조정 값 , 값이 클수록 과대적합 방지 효과
                'reg_lambda' : (1.1 , 1.5), # L2 규제 조정값 , 값이 클수록 과대적합 방지 효과
                'scale_pos_weight' : (1.4 , 1.6), # 뷸균형 데이터 가중치 조정 값 ,
                # 타깃값이 불균형할 때 양성 값에 scale_pos_weight 만큼 가중치를 줘서 균형을 맞춤(타깃값 1을 양성 값으로 간주)
                # 일반적으로 scale_pos_weight 값을 (음성 타깃값 개수 / 양성 타깃값 개수) 로 설정
                'learning_rate' : (0.02, 1)} # 학습률( 부스팅 스텝을 반복하면서 모델을 업데이트하는 데 사용되는 비율)


# 값이 고정된 하이퍼파라미터

fixed_params = {'objective' : 'binary:logistic' ,# 훈련 목적 , binary : logistic( 확률값을 구하는 이진분류)

                # reg : squarederror (회귀 문제)
                # 소프트맥스 함수를 사용하는 다중분류에서는 multi : softmax 사용
                # 확률값을 구하는 다중분류에서는 'multi : softprob' 사용

                'random_state' : 1991} # 랜덤 시드값(코드를 반복 실행해도 같은 결과가 나오게 지정하는 값)

# %%
from sklearn.metrics import accuracy_score , f1_score
from xgboost import XGBClassifier

def eval_function(max_depth, learning_rate, subsample, colsample_bytree, min_child_weight, reg_alpha, gamma, reg_lambda, scale_pos_weight):
    params = {'max_depth': int(round(max_depth)),
              'learning_rate': learning_rate,
              'subsample': subsample,
              'colsample_bytree': colsample_bytree,
              'min_child_weight': min_child_weight,
              'gamma': gamma,
              'reg_alpha': reg_alpha,
              'reg_lambda': reg_lambda,
              'scale_pos_weight': scale_pos_weight}

    params.update(fixed_params)

    print('하이퍼파라미터:', params)
    xgb_model = XGBClassifier.train(params = params , # XGBoost 모델의 하이퍼파라미터 목록 , 딕셔너리 타입으로 전달
                      dtrain = bayes_dtrain, # 훈련 데이터셋, xgboost.DMatrix 타입으로 전달
                      num_boost_round= 2000, # 부스팅 반복 횟수, 정수형 타입으로 전달
                      # num_boost_round 값이 클수록 성능이 좋아질 수 있으나 과대적합의 우려가 있다.
                      # num_boost_round 값이 작으면 반복 횟수가 줄어들어 훈련 시간이 짧아진다.
                      # 일반적으로 num_boost_round를 늘리면 learning_rate를 줄여야 한다.

                      evals = [(bayes_dvalid , ' bayes_dvalid')],
                      # 모델 성능 평가용 검증 데이터셋
                      # (DMatrix, 문자열) 쌍들을 원소로 갖는 리스트 타입으로 전달, 검증 데이터셋 이름을 원하는 대로 문자열로 정하면 된다.
                      maximize = True, # feval 평가지수가 높으면 좋은지 여부
                      feval = accuracy_scorer(), # 검증용 평가지표, 사용자 정의 함수 형태
                      # evals를 활용해 모델 성능을 검증할 때 사용할 사용자 정의 평가지표 함수
                      # 예측값과 실제값을 파라미터로 전달받아, 평가지표명과 평가점수를 반환하는 함수이다.
                      early_stopping_rounds= 200,
                      # 조기종료 조건
                      # 모델은 기본적으로 num_boost_round만큼 훈련을 반복하며, 매 이터레이션마다 evals로 모델 성능을 평가하여 성능이 연속으로
                      # 좋아지지 않는다면 훈련을 중단하는데, 훈련 중단에 필요한 최소횟수가 early_stopping_rounds 이다. 즉 , early_stopping_rounds
                      # 동안 모델 성능이 좋아지지 않는다면 훈련을 중단한다.

                      # 과대적합 방지 효과

                      # 조기종료를 적용하기 위해서는 evals 에 검증 데이터가 하나 이상 있어야한다. 또한 evals에 검증 데이터가 여러 개라면 마지막 검증
                      # 데이터를 기준으로 조기종료 조건을 적용한다.


                      verbose_eval= False) # 성능 점수 로그 설정 값
# True 로 설정하면 매 부스팅 스텝마다 평가점수르 출력
# 출력값이 너무 많아지는 것을 방지하기위해 verbose_eval로 설정

best_iter = xgb_model.best_iteration # 최적 반복횟수

    y_preds = model.predict(X_valid)
    # 정확도 계산
    accuracy = accuracy_score(y_valid, y_preds)
    print(f'Accuracy: {accuracy}\n')

    f1 = f1_score(y_valid, y_pred)
    print(f'f1_score: {f1}\n')

    return accuracy , f1

# 이하 생략

# %%
# %%time

from bayes_opt import BayesianOptimization

# 베이지안 최적화 객체 생성

optimizer = BayesianOptimization(f= eval_function, pbounds = param_bounds , random_state= 0)


# 베이지안 최적화 수행


optimizer.maximize(init_points= 3 , n_iter= 6)
# Out:
# |   iter    |  target   | colsam... |   gamma   | learni... | max_depth | min_ch... | reg_alpha | reg_la... | scale_... | subsample |
# -------------------------------------------------------------------------------------------------------------------------------------
# 하이퍼파라미터: {'max_depth': 7, 'learning_rate': 0.610708108550211, 'subsample': 0.9818313802505146, 'colsample_bytree': 0.6841694527491273, 'min_child_weight': 7.118273996694524, 'gamma': 10.14556809911726, 'reg_alpha': 8.291788226133312, 'reg_lambda': 1.275034884505077, 'scale_pos_weight': 1.578354600156416, 'objective': 'binary:logistic', 'random_state': 1991}
# C:\Users\andyp\anaconda3\lib\site-packages\xgboost\sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# Accuracy: 0.825
#
# f1_score: 0.7963800904977376
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <timed exec> in <module>
#
# ~\anaconda3\lib\site-packages\bayes_opt\bayesian_optimization.py in maximize(self, init_points, n_iter, acquisition_function, acq, kappa, kappa_decay, kappa_decay_delay, xi, **gp_params)
#     309                 x_probe = self.suggest(util)
#     310                 iteration += 1
# --> 311             self.probe(x_probe, lazy=False)
#     312
#     313             if self._bounds_transformer and iteration > 0:
#
# ~\anaconda3\lib\site-packages\bayes_opt\bayesian_optimization.py in probe(self, params, lazy)
#     206             self._queue.add(params)
#     207         else:
# --> 208             self._space.probe(params)
#     209             self.dispatch(Events.OPTIMIZATION_STEP)
#     210
#
# ~\anaconda3\lib\site-packages\bayes_opt\target_space.py in probe(self, params)
#     237
#     238         if self._constraint is None:
# --> 239             self.register(x, target)
#     240             return target
#     241         else:
#
# ~\anaconda3\lib\site-packages\bayes_opt\target_space.py in register(self, params, target, constraint_value)
#     198
#     199         self._params = np.concatenate([self._params, x.reshape(1, -1)])
# --> 200         self._target = np.concatenate([self._target, [target]])
#     201
#     202         if self._constraint is None:
#
# ~\anaconda3\lib\site-packages\numpy\core\overrides.py in concatenate(*args, **kwargs)
#
# ValueError: all the input arrays must have same number of dimensions, but the array at index 0 has 1 dimension(s) and the array at index 1 has 2 dimension(s)

# %%
# 평가함수 점수가 최대일 대 하이퍼파라미터
max_params = optimizer.max['params']
max_params
max_params['max_depth'] = int(round(max_params['max_depth']))

max_params.update(fixed_params)
max_params
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-504782892541> in <module>
#       1 # 평가함수 점수가 최대일 대 하이퍼파라미터
# ----> 2 max_params = optimizer.max['params']
#       3 max_params
#       4 max_params['max_depth'] = int(round(max_params['max_depth']))
#       5
#
# KeyError: 'params'

# %%
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.metrics import accuracy_score
import numpy as np

# 층화 K 폴드 교차 검증기 생성
folds = KFold(n_splits=5, shuffle=True, random_state=1991)

# OOF 방식으로 훈련된 모델로 검증 데이터 타깃값을 예측한 확률을 담을 1차원 배열
oof_val_preds = np.zeros(X.shape[0])

# OOF 방식으로 훈련된 모델로 테스트 데이터 타깃값을 예측한 확률을 담을 1차원 배열
oof_test_preds = np.zeros(X_test.shape[0])

# OOF 방식으로 모델 훈련, 검증, 예측
for idx, (train_idx, valid_idx) in enumerate(folds.split(X, y)):
    # 각 폴드를 구분하는 문구 출력
    print('#' * 40, f'폴드 {idx+1} / 폴드 {folds.n_splits}', '#' * 40)

    # 훈련용 데이터, 검증용 데이터 설정
    X_train, y_train = X[train_idx], y[train_idx]
    X_valid, y_valid = X[valid_idx], y[valid_idx]

    # XGBoost 모델 훈련
    xgb_model = XGBClassifier(**max_params)
    xgb_model.fit(X_train, y_train)

    # 검증 데이터 예측 확률에 대한 정확도
    preds = xgb_model.predict(X_valid)
    accuracy = accuracy_score(y_valid, preds)
    print(f'폴드 {idx+1}  Accuracy: {accuracy}\n')

    # 모델 성능이 가장 좋을 때의 모델로 테스트 데이터 예측
    test_preds = xgb_model.predict(X_test)

    # 검증 데이터 예측 확률을 전체 데이터에 저장
    oof_val_preds[valid_idx] = preds

    # 테스트 데이터 예측 확률을 전체 데이터에 누적하여 저장
    oof_test_preds += test_preds

# OOF 검증 데이터 예측 확률을 이진 분류로 변환
oof_val_preds_binary = np.where(oof_val_preds >= 0.5, 1, 0)

# OOF 검증 데이터 정확도 계산
oof_accuracy = accuracy_score(y, oof_val_preds_binary)
print(f'OOF Accuracy: {oof_accuracy}\n')

# OOF 테스트 데이터 예측 확률의 평균 계산
oof_test_preds /= folds.n_splits

# OOF 테스트 데이터 예측 확률을 이진 분류로 변환
oof_test_preds_binary = np.where(oof_test_preds >= 0.5, 1, 0)
# Out:
# ######################################## 폴드 1 / 폴드 5 ########################################
# 폴드 1  Accuracy: 0.795
#
# ######################################## 폴드 2 / 폴드 5 ########################################
# 폴드 2  Accuracy: 0.795
#
# ######################################## 폴드 3 / 폴드 5 ########################################
# 폴드 3  Accuracy: 0.84
#
# ######################################## 폴드 4 / 폴드 5 ########################################
# 폴드 4  Accuracy: 0.84
#
# ######################################## 폴드 5 / 폴드 5 ########################################
# 폴드 5  Accuracy: 0.845
#
# OOF Accuracy: 0.823

# %%
oof_test_preds
# Out:
# array([1. , 0. , 0.4, ..., 1. , 0. , 1. ])

# %%
# OOF 테스트 데이터 예측 확률 저장
df_preds = pd.DataFrame(oof_test_preds_binary, columns=['Solution'])
df_preds.index += 1  # 인덱스를 1부터 시작하도록 수정

# %%
df_preds.index.name= 'Id'
df_preds
# Out:
#       Solution
# Id
# 1            1
# 2            0
# 3            0
# 4            0
# 5            1
# ...        ...
# 8996         1
# 8997         1
# 8998         1
# 8999         0
# 9000         1
#
# [9000 rows x 1 columns]

# %%
import datetime

# 현재 날짜와 시각 구하기
now = datetime.datetime.now()
date_list = [now.month, now.day, now.hour, now.minute, now.second]
# 현재 날짜와 시각 출력하기
print("현재 날짜 및 시각 : ", date_list)

# 제출 파일 생성

# submission['Survived'] = y_preds
df_preds.to_csv(f'XGBClassifier_{date_list[0]}_{date_list[1]}_{date_list[2]}_{date_list[3]}_{date_list[4]}.csv')
# Out:
# 현재 날짜 및 시각 :  [6, 16, 1, 14, 1]

# %%
import optuna
import numpy as np
import xgboost as xgb
from sklearn.datasets import load_iris
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score

# 데이터 로드
X = sparse.csr_matrix(train)
X_test = sparse.csr_matrix(test)


y = trainLabels['predict'].values

# Objective 함수 정의 (하이퍼파라미터 최적화 목적 함수)
def objective(trial):
    param = {
        'objective': 'binary:logistic',
        'eval_metric': 'logloss',
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.1),
        'subsample': trial.suggest_uniform('subsample', 0.5, 1),
        'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1),
        'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'scale_pos_weight': trial.suggest_uniform('scale_pos_weight', 1, 10)
    }

    # K-Fold 교차 검증
    kf = KFold(n_splits=5, random_state=42, shuffle=True)
    accuracy_scores = []

    for train_idx, valid_idx in kf.split(X):
        X_train, X_valid = X[train_idx], X[valid_idx]
        y_train, y_valid = y[train_idx], y[valid_idx]

        model = xgb.XGBClassifier(**param)
        model.fit(X_train, y_train)
        y_pred = model.predict(X_valid)
        accuracy = accuracy_score(y_valid, y_pred)
        accuracy_scores.append(accuracy)

    return np.mean(accuracy_scores)

# Optuna 베이지안 최적화 실행
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)

# 최적의 하이퍼파라미터 출력
best_params = study.best_params
print("Best Params:", best_params)

# 최적의 하이퍼파라미터로 모델 훈련
kf = KFold(n_splits=5, random_state=42, shuffle=True)
accuracy_scores = []

for train_idx, valid_idx in kf.split(X):
    X_train, X_valid = X[train_idx], X[valid_idx]
    y_train, y_valid = y[train_idx], y[valid_idx]

    model = xgb.XGBClassifier(**best_params)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_valid)
    accuracy = accuracy_score(y_valid, y_pred)
    accuracy_scores.append(accuracy)

# K-Fold 교차 검증 평균 정확도 출력
print("Mean Accuracy:", np.mean(accuracy_scores))

# 전체 데이터로 최적의 하이퍼파라미터로 모델 훈련
final_model = xgb.XGBClassifier(**best_params)
final_model.fit(X, y)
# Out:
# [I 2023-06-16 01:34:26,658] A new study created in memory with name: no-name-688805ad-68ae-4db3-bbc9-460f3b3fe90a
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:22: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:23: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:24: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:26: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'scale_pos_weight': trial.suggest_uniform('scale_pos_weight', 1, 10)
# [I 2023-06-16 01:34:27,557] Trial 0 finished with value: 0.798 and parameters: {'max_depth': 7, 'learning_rate': 0.015989175300782768, 'subsample': 0.5037274752922851, 'colsample_bytree': 0.9914843012648422, 'gamma': 1.3443758899535113e-08, 'min_child_weight': 3, 'scale_pos_weight': 7.648448818524399}. Best is trial 0 with value: 0.798.
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:22: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:23: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:24: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:26: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'scale_pos_weight': trial.suggest_uniform('scale_pos_weight', 1, 10)
# [I 2023-06-16 01:34:28,547] Trial 1 finished with value: 0.8300000000000001 and parameters: {'max_depth': 7, 'learning_rate': 0.026725423589775067, 'subsample': 0.8634246307305281, 'colsample_bytree': 0.6324308031038319, 'gamma': 0.0006675214650905449, 'min_child_weight': 3, 'scale_pos_weight': 6.157475288591773}. Best is trial 1 with value: 0.8300000000000001.
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:22: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:23: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:24: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:26: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'scale_pos_weight': trial.suggest_uniform('scale_pos_weight', 1, 10)
# [I 2023-06-16 01:34:29,071] Trial 2 finished with value: 0.8559999999999999 and parameters: {'max_depth': 7, 'learning_rate': 0.05681139437102218, 'subsample': 0.659315420461578, 'colsample_bytree': 0.5330413485612, 'gamma': 0.051758447230016956, 'min_child_weight': 9, 'scale_pos_weight': 1.6563311419127627}. Best is trial 2 with value: 0.8559999999999999.
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:22: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:23: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:24: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:26: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'scale_pos_weight': trial.suggest_uniform('scale_pos_weight', 1, 10)
# [I 2023-06-16 01:34:30,115] Trial 3 finished with value: 0.8380000000000001 and parameters: {'max_depth': 9, 'learning_rate': 0.01959828124501591, 'subsample': 0.9256966390881395, 'colsample_bytree': 0.8611521463811421, 'gamma': 0.0038338890855433416, 'min_child_weight': 6, 'scale_pos_weight': 3.589721156252163}. Best is trial 2 with value: 0.8559999999999999.
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:22: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:23: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:24: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:26: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'scale_pos_weight': trial.suggest_uniform('scale_pos_weight', 1, 10)
# [I 2023-06-16 01:34:30,863] Trial 4 finished with value: 0.829 and parameters: {'max_depth': 7, 'learning_rate': 0.04716066655938678, 'subsample': 0.7579951021797176, 'colsample_bytree': 0.6665294287404108, 'gamma': 0.0004565558237772712, 'min_child_weight': 7, 'scale_pos_weight': 7.290937369553818}. Best is trial 2 with value: 0.8559999999999999.
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:22: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:23: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:24: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:26: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'scale_pos_weight': trial.suggest_uniform('scale_pos_weight', 1, 10)
# [I 2023-06-16 01:34:31,453] Trial 5 finished with value: 0.734 and parameters: {'max_depth': 4, 'learning_rate': 0.023476752455443534, 'subsample': 0.8389383229417322, 'colsample_bytree': 0.5695691261283329, 'gamma': 0.02237920197953178, 'min_child_weight': 5, 'scale_pos_weight': 9.7004830352207}. Best is trial 2 with value: 0.8559999999999999.
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:22: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:23: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:24: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:26: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'scale_pos_weight': trial.suggest_uniform('scale_pos_weight', 1, 10)
# [I 2023-06-16 01:34:32,486] Trial 6 finished with value: 0.868 and parameters: {'max_depth': 8, 'learning_rate': 0.03417821983423961, 'subsample': 0.962503079780352, 'colsample_bytree': 0.554311145487566, 'gamma': 1.28666359247416e-06, 'min_child_weight': 1, 'scale_pos_weight': 3.607806648272755}. Best is trial 6 with value: 0.868.
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:22: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:23: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:24: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:26: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'scale_pos_weight': trial.suggest_uniform('scale_pos_weight', 1, 10)
# [I 2023-06-16 01:34:33,284] Trial 7 finished with value: 0.8190000000000002 and parameters: {'max_depth': 8, 'learning_rate': 0.012227382160091312, 'subsample': 0.6142609450038117, 'colsample_bytree': 0.9032386541140184, 'gamma': 2.8783325287556473e-06, 'min_child_weight': 6, 'scale_pos_weight': 3.066585092519752}. Best is trial 6 with value: 0.868.
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:22: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:23: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:24: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:26: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'scale_pos_weight': trial.suggest_uniform('scale_pos_weight', 1, 10)
# [I 2023-06-16 01:34:34,098] Trial 8 finished with value: 0.8719999999999999 and parameters: {'max_depth': 8, 'learning_rate': 0.034534460785035616, 'subsample': 0.9799363437661184, 'colsample_bytree': 0.8383957941963269, 'gamma': 7.348894139229207e-05, 'min_child_weight': 7, 'scale_pos_weight': 1.9772163282943747}. Best is trial 8 with value: 0.8719999999999999.
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:22: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:23: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:24: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:26: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'scale_pos_weight': trial.suggest_uniform('scale_pos_weight', 1, 10)
# [I 2023-06-16 01:34:34,862] Trial 9 finished with value: 0.7539999999999999 and parameters: {'max_depth': 9, 'learning_rate': 0.010039366163575418, 'subsample': 0.5863007912598459, 'colsample_bytree': 0.9613958457324321, 'gamma': 0.00014909840594168412, 'min_child_weight': 9, 'scale_pos_weight': 5.231753793330901}. Best is trial 8 with value: 0.8719999999999999.
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:22: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:23: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:24: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:26: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'scale_pos_weight': trial.suggest_uniform('scale_pos_weight', 1, 10)
# [I 2023-06-16 01:34:35,442] Trial 10 finished with value: 0.8800000000000001 and parameters: {'max_depth': 4, 'learning_rate': 0.09713655934543512, 'subsample': 0.9907084414680307, 'colsample_bytree': 0.8105075571299281, 'gamma': 0.2855761719579555, 'min_child_weight': 10, 'scale_pos_weight': 1.2651832406096046}. Best is trial 10 with value: 0.8800000000000001.
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:22: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:23: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:24: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:26: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'scale_pos_weight': trial.suggest_uniform('scale_pos_weight', 1, 10)
# [I 2023-06-16 01:34:36,023] Trial 11 finished with value: 0.884 and parameters: {'max_depth': 4, 'learning_rate': 0.08978649258028891, 'subsample': 0.9908184596985543, 'colsample_bytree': 0.7847693170018597, 'gamma': 0.47138655397967943, 'min_child_weight': 10, 'scale_pos_weight': 1.0011382757203737}. Best is trial 11 with value: 0.884.
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:22: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:23: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:24: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:26: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'scale_pos_weight': trial.suggest_uniform('scale_pos_weight', 1, 10)
# [I 2023-06-16 01:34:36,662] Trial 12 finished with value: 0.876 and parameters: {'max_depth': 4, 'learning_rate': 0.09893865351964252, 'subsample': 0.986067000938537, 'colsample_bytree': 0.7795586984427818, 'gamma': 0.8893920294650477, 'min_child_weight': 10, 'scale_pos_weight': 1.1278100895001906}. Best is trial 11 with value: 0.884.
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:22: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:23: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:24: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:26: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'scale_pos_weight': trial.suggest_uniform('scale_pos_weight', 1, 10)
# [I 2023-06-16 01:34:37,203] Trial 13 finished with value: 0.86 and parameters: {'max_depth': 3, 'learning_rate': 0.09312395897084945, 'subsample': 0.9007092649018076, 'colsample_bytree': 0.7523523736367613, 'gamma': 0.9018755358211523, 'min_child_weight': 10, 'scale_pos_weight': 1.3493767898481694}. Best is trial 11 with value: 0.884.
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:22: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:23: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:24: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:26: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'scale_pos_weight': trial.suggest_uniform('scale_pos_weight', 1, 10)
# [I 2023-06-16 01:34:38,063] Trial 14 finished with value: 0.86 and parameters: {'max_depth': 5, 'learning_rate': 0.0745096823553314, 'subsample': 0.9978121082839678, 'colsample_bytree': 0.8006901173266764, 'gamma': 0.17131947911235532, 'min_child_weight': 8, 'scale_pos_weight': 2.5327875218371023}. Best is trial 11 with value: 0.884.
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:22: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:23: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:24: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:26: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'scale_pos_weight': trial.suggest_uniform('scale_pos_weight', 1, 10)
# [I 2023-06-16 01:34:38,642] Trial 15 finished with value: 0.865 and parameters: {'max_depth': 5, 'learning_rate': 0.06343590816695141, 'subsample': 0.8140381064509656, 'colsample_bytree': 0.7092137469667533, 'gamma': 0.013874225034204598, 'min_child_weight': 10, 'scale_pos_weight': 1.0238563970676366}. Best is trial 11 with value: 0.884.
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:22: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:23: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:24: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:26: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'scale_pos_weight': trial.suggest_uniform('scale_pos_weight', 1, 10)
# [I 2023-06-16 01:34:39,216] Trial 16 finished with value: 0.836 and parameters: {'max_depth': 3, 'learning_rate': 0.07753389375003235, 'subsample': 0.907908261359835, 'colsample_bytree': 0.7223379879929048, 'gamma': 0.13853749164643187, 'min_child_weight': 8, 'scale_pos_weight': 2.599522574183818}. Best is trial 11 with value: 0.884.
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:22: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:23: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:24: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:26: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'scale_pos_weight': trial.suggest_uniform('scale_pos_weight', 1, 10)
# [I 2023-06-16 01:34:40,185] Trial 17 finished with value: 0.8459999999999999 and parameters: {'max_depth': 5, 'learning_rate': 0.04454082209502992, 'subsample': 0.9358151652709431, 'colsample_bytree': 0.8154140555716405, 'gamma': 0.9665761513448063, 'min_child_weight': 4, 'scale_pos_weight': 4.70131098069792}. Best is trial 11 with value: 0.884.
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:22: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:23: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:24: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:26: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'scale_pos_weight': trial.suggest_uniform('scale_pos_weight', 1, 10)
# [I 2023-06-16 01:34:40,911] Trial 18 finished with value: 0.8619999999999999 and parameters: {'max_depth': 4, 'learning_rate': 0.07956934356105362, 'subsample': 0.8837017496847139, 'colsample_bytree': 0.9056303099963796, 'gamma': 0.0035464734572001238, 'min_child_weight': 9, 'scale_pos_weight': 2.0633766997390204}. Best is trial 11 with value: 0.884.
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:22: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:23: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:24: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:26: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'scale_pos_weight': trial.suggest_uniform('scale_pos_weight', 1, 10)
# [I 2023-06-16 01:34:41,674] Trial 19 finished with value: 0.851 and parameters: {'max_depth': 6, 'learning_rate': 0.09642977423302419, 'subsample': 0.8034860662733541, 'colsample_bytree': 0.7481894756399128, 'gamma': 0.08884207720388346, 'min_child_weight': 8, 'scale_pos_weight': 4.060707351663536}. Best is trial 11 with value: 0.884.
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:22: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:23: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:24: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:26: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'scale_pos_weight': trial.suggest_uniform('scale_pos_weight', 1, 10)
# [I 2023-06-16 01:34:42,353] Trial 20 finished with value: 0.8399999999999999 and parameters: {'max_depth': 3, 'learning_rate': 0.05833343184731273, 'subsample': 0.9425117569229161, 'colsample_bytree': 0.7879018540529068, 'gamma': 0.007827130852499128, 'min_child_weight': 1, 'scale_pos_weight': 2.8210667587513303}. Best is trial 11 with value: 0.884.
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:22: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:23: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:24: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:26: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'scale_pos_weight': trial.suggest_uniform('scale_pos_weight', 1, 10)
# [I 2023-06-16 01:34:43,009] Trial 21 finished with value: 0.882 and parameters: {'max_depth': 4, 'learning_rate': 0.08953200825131798, 'subsample': 0.9991578422834193, 'colsample_bytree': 0.7733953866975511, 'gamma': 0.6488128381932502, 'min_child_weight': 10, 'scale_pos_weight': 1.1852864499971134}. Best is trial 11 with value: 0.884.
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:22: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:23: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:24: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:26: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'scale_pos_weight': trial.suggest_uniform('scale_pos_weight', 1, 10)
# [I 2023-06-16 01:34:43,687] Trial 22 finished with value: 0.8690000000000001 and parameters: {'max_depth': 4, 'learning_rate': 0.07183335745218368, 'subsample': 0.9991472778422626, 'colsample_bytree': 0.8719263421042803, 'gamma': 0.20062495486417042, 'min_child_weight': 10, 'scale_pos_weight': 1.7846078523946158}. Best is trial 11 with value: 0.884.
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:22: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1),
# ...
#   'scale_pos_weight': trial.suggest_uniform('scale_pos_weight', 1, 10)
# [I 2023-06-16 01:35:38,279] Trial 92 finished with value: 0.885 and parameters: {'max_depth': 9, 'learning_rate': 0.08580314565098478, 'subsample': 0.8895738811121812, 'colsample_bytree': 0.7349532165163428, 'gamma': 0.0255795084031717, 'min_child_weight': 6, 'scale_pos_weight': 1.2471343730528082}. Best is trial 55 with value: 0.892.
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:22: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:23: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:24: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:26: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'scale_pos_weight': trial.suggest_uniform('scale_pos_weight', 1, 10)
# [I 2023-06-16 01:35:38,999] Trial 93 finished with value: 0.876 and parameters: {'max_depth': 8, 'learning_rate': 0.07503520767744182, 'subsample': 0.9043425808253424, 'colsample_bytree': 0.7533650787919953, 'gamma': 0.13935858775628532, 'min_child_weight': 7, 'scale_pos_weight': 2.0879002005113554}. Best is trial 55 with value: 0.892.
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:22: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:23: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:24: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:26: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'scale_pos_weight': trial.suggest_uniform('scale_pos_weight', 1, 10)
# [I 2023-06-16 01:35:39,725] Trial 94 finished with value: 0.8880000000000001 and parameters: {'max_depth': 9, 'learning_rate': 0.09561405873280392, 'subsample': 0.8548010483295845, 'colsample_bytree': 0.7753311509521668, 'gamma': 0.034661093720828255, 'min_child_weight': 5, 'scale_pos_weight': 1.4169946020799402}. Best is trial 55 with value: 0.892.
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:22: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:23: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:24: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:26: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'scale_pos_weight': trial.suggest_uniform('scale_pos_weight', 1, 10)
# [I 2023-06-16 01:35:40,412] Trial 95 finished with value: 0.89 and parameters: {'max_depth': 9, 'learning_rate': 0.08896370425334976, 'subsample': 0.8533464051063733, 'colsample_bytree': 0.7679143430240021, 'gamma': 0.04162652161450159, 'min_child_weight': 5, 'scale_pos_weight': 1.00414772122654}. Best is trial 55 with value: 0.892.
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:22: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:23: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:24: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:26: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'scale_pos_weight': trial.suggest_uniform('scale_pos_weight', 1, 10)
# [I 2023-06-16 01:35:41,174] Trial 96 finished with value: 0.885 and parameters: {'max_depth': 8, 'learning_rate': 0.08915457203843742, 'subsample': 0.8534632546152728, 'colsample_bytree': 0.7678116361241035, 'gamma': 0.03539278100913153, 'min_child_weight': 5, 'scale_pos_weight': 1.0784471990598172}. Best is trial 55 with value: 0.892.
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:22: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:23: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:24: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:26: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'scale_pos_weight': trial.suggest_uniform('scale_pos_weight', 1, 10)
# [I 2023-06-16 01:35:41,956] Trial 97 finished with value: 0.8780000000000001 and parameters: {'max_depth': 10, 'learning_rate': 0.08206777652591846, 'subsample': 0.8488423373240036, 'colsample_bytree': 0.7256873723142825, 'gamma': 0.015390560334751755, 'min_child_weight': 5, 'scale_pos_weight': 1.532606113180408}. Best is trial 55 with value: 0.892.
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:22: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:23: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:24: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:26: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'scale_pos_weight': trial.suggest_uniform('scale_pos_weight', 1, 10)
# [I 2023-06-16 01:35:42,825] Trial 98 finished with value: 0.8709999999999999 and parameters: {'max_depth': 9, 'learning_rate': 0.07425737902541919, 'subsample': 0.9140549010777235, 'colsample_bytree': 0.7400465077556544, 'gamma': 0.005620590963449545, 'min_child_weight': 5, 'scale_pos_weight': 1.0084531767256764}. Best is trial 55 with value: 0.892.
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:22: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:23: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:24: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
# C:\Users\park sung hyuk95\AppData\Local\Temp\ipykernel_27320\3448487724.py:26: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'scale_pos_weight': trial.suggest_uniform('scale_pos_weight', 1, 10)
# [I 2023-06-16 01:35:43,659] Trial 99 finished with value: 0.8859999999999999 and parameters: {'max_depth': 9, 'learning_rate': 0.0993109228701912, 'subsample': 0.8622941473185591, 'colsample_bytree': 0.7789671147286972, 'gamma': 0.01037357292463267, 'min_child_weight': 4, 'scale_pos_weight': 1.4222056799889924}. Best is trial 55 with value: 0.892.
# Best Params: {'max_depth': 9, 'learning_rate': 0.09356744161198766, 'subsample': 0.8708506054774197, 'colsample_bytree': 0.7508437816321226, 'gamma': 0.6711120482414766, 'min_child_weight': 5, 'scale_pos_weight': 1.1540870582999168}
# Mean Accuracy: 0.892
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.7508437816321226, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=0.6711120482414766, gpu_id=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.09356744161198766, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=9, max_leaves=None,
#               min_child_weight=5, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
# !pip install --trusted-host pypi.python.org --trusted-host files.pythonhosted.org --trusted-host pypi.org optuna
# Out:
# Collecting optunaNote: you may need to restart the kernel to use updated packages.
#
#   Downloading optuna-3.2.0-py3-none-any.whl (390 kB)
#      -------------------------------------- 390.6/390.6 kB 8.1 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML in c:\users\park sung hyuk95\anaconda3\lib\site-packages (from optuna) (6.0)
# Requirement already satisfied: numpy in c:\users\park sung hyuk95\appdata\roaming\python\python39\site-packages (from optuna) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\park sung hyuk95\anaconda3\lib\site-packages (from optuna) (21.3)
# Collecting alembic>=1.5.0
#   Downloading alembic-1.11.1-py3-none-any.whl (224 kB)
#      ------------------------------------- 224.5/224.5 kB 13.4 MB/s eta 0:00:00
# Collecting cmaes>=0.9.1
#   Downloading cmaes-0.9.1-py3-none-any.whl (21 kB)
# Requirement already satisfied: tqdm in c:\users\park sung hyuk95\anaconda3\lib\site-packages (from optuna) (4.64.1)
# Collecting colorlog
#   Downloading colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: sqlalchemy>=1.3.0 in c:\users\park sung hyuk95\anaconda3\lib\site-packages (from optuna) (1.4.39)
# Collecting Mako
#   Downloading Mako-1.2.4-py3-none-any.whl (78 kB)
#      ---------------------------------------- 78.7/78.7 kB 4.3 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4 in c:\users\park sung hyuk95\anaconda3\lib\site-packages (from alembic>=1.5.0->optuna) (4.3.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\park sung hyuk95\anaconda3\lib\site-packages (from packaging>=20.0->optuna) (3.0.9)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\park sung hyuk95\anaconda3\lib\site-packages (from sqlalchemy>=1.3.0->optuna) (1.1.1)
# Requirement already satisfied: colorama in c:\users\park sung hyuk95\anaconda3\lib\site-packages (from colorlog->optuna) (0.4.6)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\users\park sung hyuk95\anaconda3\lib\site-packages (from Mako->alembic>=1.5.0->optuna) (2.0.1)
# Installing collected packages: Mako, colorlog, cmaes, alembic, optuna
# Successfully installed Mako-1.2.4 alembic-1.11.1 cmaes-0.9.1 colorlog-6.7.0 optuna-3.2.0
# Requirement already satisfied: optuna in c:\users\park sung hyuk95\anaconda3\lib\site-packages (3.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\park sung hyuk95\anaconda3\lib\site-packages (from optuna) (21.3)
# Requirement already satisfied: numpy in c:\users\park sung hyuk95\appdata\roaming\python\python39\site-packages (from optuna) (1.24.3)
# Requirement already satisfied: colorlog in c:\users\park sung hyuk95\anaconda3\lib\site-packages (from optuna) (6.7.0)
# Requirement already satisfied: cmaes>=0.9.1 in c:\users\park sung hyuk95\anaconda3\lib\site-packages (from optuna) (0.9.1)
# Requirement already satisfied: PyYAML in c:\users\park sung hyuk95\anaconda3\lib\site-packages (from optuna) (6.0)
# Requirement already satisfied: sqlalchemy>=1.3.0 in c:\users\park sung hyuk95\anaconda3\lib\site-packages (from optuna) (1.4.39)
# Requirement already satisfied: alembic>=1.5.0 in c:\users\park sung hyuk95\anaconda3\lib\site-packages (from optuna) (1.11.1)
# Requirement already satisfied: tqdm in c:\users\park sung hyuk95\anaconda3\lib\site-packages (from optuna) (4.64.1)
# Requirement already satisfied: typing-extensions>=4 in c:\users\park sung hyuk95\anaconda3\lib\site-packages (from alembic>=1.5.0->optuna) (4.3.0)
# Requirement already satisfied: Mako in c:\users\park sung hyuk95\anaconda3\lib\site-packages (from alembic>=1.5.0->optuna) (1.2.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\park sung hyuk95\anaconda3\lib\site-packages (from packaging>=20.0->optuna) (3.0.9)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\park sung hyuk95\anaconda3\lib\site-packages (from sqlalchemy>=1.3.0->optuna) (1.1.1)
# Requirement already satisfied: colorama in c:\users\park sung hyuk95\anaconda3\lib\site-packages (from colorlog->optuna) (0.4.6)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\users\park sung hyuk95\anaconda3\lib\site-packages (from Mako->alembic>=1.5.0->optuna) (2.0.1)

# %%
final_model.predict(X_test)
final_model
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.7508437816321226, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=0.6711120482414766, gpu_id=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.09356744161198766, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=9, max_leaves=None,
#               min_child_weight=5, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)
